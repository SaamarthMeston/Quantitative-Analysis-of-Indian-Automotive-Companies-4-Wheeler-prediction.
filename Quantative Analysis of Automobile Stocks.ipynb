# %% [markdown]
# ###### Quantitative Analysis of Automative Companies Listed in Indian Stock Market And Predictive model for Tata Motors.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
pio.templates.default = "plotly_white"

# %%
Auto_df = pd.read_csv(r'C:\Users\Asus\Desktop\Stock Market Projcet\Stock Market\Union\AutoMotive_Stocks.csv')

# %%
Auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2982 entries, 0 to 2981
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           2982 non-null   object
#  1   Date           2982 non-null   object
#  2   OPEN           2982 non-null   float64
#  3   HIGH           2982 non-null   float64
#  4   LOW            2982 non-null   float64
#  5   PREV. CLOSE    2982 non-null   float64
#  6   ltp            2982 non-null   float64
#  7   close          2982 non-null   float64
#  8   vwap           2982 non-null   float64
#  9   52W H          2982 non-null   float64
#  10  52W L          2982 non-null   float64
#  11  VOLUME         2982 non-null   int64
#  12  VALUE          2982 non-null   float64
#  13  No of trades   2982 non-null   int64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 326.3+ KB

# %%
Auto_df.describe(include= 'all')
# Out:
#         Name       Date          OPEN          HIGH           LOW   \
# count   2982        2982   2982.000000   2982.000000   2982.000000
# unique     3         994           NaN           NaN           NaN
# top      M&M  06-03-2024           NaN           NaN           NaN
# freq     994           3           NaN           NaN           NaN
# mean     NaN         NaN   3156.859339   3192.783602   3118.062693
# std      NaN         NaN   3580.056278   3616.030567   3541.083828
# min      NaN         NaN     66.500000     66.900000     63.500000
# 25%      NaN         NaN    475.000000    481.112500    468.100000
# 50%      NaN         NaN    908.625000    920.100000    893.850000
# 75%      NaN         NaN   7060.000000   7138.750000   6970.262500
# max      NaN         NaN  11704.950000  11730.000000  11561.800000
#
#         PREV. CLOSE           ltp         close          vwap         52W H   \
# count    2982.000000   2982.000000   2982.000000   2982.000000   2982.000000
# ...

# %%
Auto_df.columns
# Out:
# Index(['Name', 'Date ', 'OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ',
#        'close ', 'vwap ', '52W H ', '52W L ', 'VOLUME ', 'VALUE ',
#        'No of trades '],
#       dtype='object')

# %%
Auto_df.columns = Auto_df.columns.str.replace(" ",'')

# %%
Auto_df.rename(columns = {'Nooftrades':'No of trades'}, inplace =True)

# %%
Auto_df['Date'] = pd.to_datetime(Auto_df['Date'], format= '%d-%m-%Y')

# %%
Auto_df.describe()
# Out:
#                                 Date          OPEN          HIGH  \
# count                           2982   2982.000000   2982.000000
# mean   2022-03-09 07:29:05.674044160   3156.859339   3192.783602
# min              2020-03-09 00:00:00     66.500000     66.900000
# 25%              2021-03-05 00:00:00    475.000000    481.112500
# 50%              2022-03-08 12:00:00    908.625000    920.100000
# 75%              2023-03-08 00:00:00   7060.000000   7138.750000
# max              2024-03-06 00:00:00  11704.950000  11730.000000
# std                              NaN   3580.056278   3616.030567
#
#                 LOW    PREV.CLOSE           ltp         close          vwap  \
# count   2982.000000   2982.000000   2982.000000   2982.000000   2982.000000
# mean    3118.062693   3152.226911   3154.089873   3154.750117   3155.797522
# min       63.500000     65.300000     65.450000     65.300000     65.500000
# ...

# %%
Disp_stats = Auto_df.groupby('Name')['close']
Disp_stats.describe().T
# Out:
# Name           M&M       Maruti  TATA MOTORS
# count   994.000000    994.00000   994.000000
# mean   1019.413581   8043.16499   401.671781
# std     378.416426   1475.60563   198.975524
# min     269.000000   4011.50000    65.300000
# 25%     759.437500   7059.06250   294.475000
# 50%     890.950000   7822.42500   418.000000
# 75%    1299.437500   8949.25000   496.850000
# max    1972.950000  11670.60000  1021.900000

# %%
close_v_comp = Auto_df.pivot(index='Date',columns ='Name', values='close')

# %%
close_v_comp
# Out:
# Name            M&M    Maruti  TATA MOTORS
# Date
# 2020-03-09   463.20   6201.10       105.70
# 2020-03-11   451.60   6146.30        98.90
# 2020-03-12   423.35   5643.15        88.00
# 2020-03-13   428.85   5838.60        89.75
# 2020-03-16   391.80   5480.25        82.95
# ...             ...       ...          ...
# 2024-03-01  1972.95  11620.95       977.40
# 2024-03-02  1960.10  11567.20       988.35
# 2024-03-04  1921.05  11594.15       987.20
# 2024-03-05  1939.25  11670.60      1021.90
# 2024-03-06  1970.65  11567.05      1017.65
#
# [994 rows x 3 columns]

# %%
fig= make_subplots(rows= 1,cols =1)
for cols in close_v_comp.columns:
    fig.add_trace(go.Scatter(x=close_v_comp.index, y=close_v_comp[cols], name = cols), row =1, col=1)
fig.update_layout(
title_text='Time Series of Closing Prices',
xaxis_title='Date',
yaxis_title ='Closing Price')
fig.show()
# Out:
# <div>                            <div id="4df4e3df-f907-41f1-8bad-ee05a8cf3907" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4df4e3df-f907-41f1-8bad-ee05a8cf3907")) {                    Plotly.newPlot(                        "4df4e3df-f907-41f1-8bad-ee05a8cf3907",                        [{"name":"M&M","x":["2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04
# ...

# %%
volatility = close_v_comp.std().sort_values(ascending=False)

fig = px.bar(volatility,
             x=volatility.index,
             y=volatility.values,
             labels={'y': 'Standard Deviation', 'x': 'Ticker'},
             title='Volatility of Closing Prices (Standard Deviation)')

# Show the figure
fig.show()
# Out:
# <div>                            <div id="16dc23e5-ba47-4f91-b4ce-18425dd9ebe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16dc23e5-ba47-4f91-b4ce-18425dd9ebe0")) {                    Plotly.newPlot(                        "16dc23e5-ba47-4f91-b4ce-18425dd9ebe0",                        [{"alignmentgroup":"True","hovertemplate":"Name=%{x}<br>Standard Deviation=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Maruti","M&M","TATA MOTORS"],"xaxis":"x","y":[1475.6056296539793,378.41642552138313,198.97552447810656],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"hist
# ...

# %%
correlation_matrix = close_v_comp.corr()

fig = go.Figure(data=go.Heatmap(
                    z=correlation_matrix,
                    x=correlation_matrix.columns,
                    y=correlation_matrix.columns,
                    colorscale='blues',
                    colorbar=dict(title='Correlation'),
                    ))

# Update layout
fig.update_layout(
    title='Correlation Matrix of Closing Prices',
    xaxis_title='Ticker',
    yaxis_title='Ticker'
)

# Show the figure
fig.show()
# Out:
# <div>                            <div id="c38922b1-49ff-4bce-b44b-676db6054f82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c38922b1-49ff-4bce-b44b-676db6054f82")) {                    Plotly.newPlot(                        "c38922b1-49ff-4bce-b44b-676db6054f82",                        [{"colorbar":{"title":{"text":"Correlation"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"x":["M&M","Maruti","TATA MOTORS"],"y":["M&M","Maruti","TATA MOTORS"],"z":[[1.0,0.9590726954268995,0.9026633894051531],[0.9590726954268995,1.0,0.8991391426640942],[0.90266338940515
# ...

# %%
Perc_4Yrs=((close_v_comp.iloc[-1]-close_v_comp.iloc[0])/close_v_comp.iloc[0])*100
fig = px.bar(Perc_4Yrs,
             x=Perc_4Yrs.index,
             y=Perc_4Yrs.values,
             labels={'y': 'Percentage Change (%)', 'x': 'Name'},
             title='Percentage Change in Closing Prices since covid')
fig.show()
# Out:
# <div>                            <div id="7a2e280e-2f9e-45cf-8d40-3b17b46779a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a2e280e-2f9e-45cf-8d40-3b17b46779a3")) {                    Plotly.newPlot(                        "7a2e280e-2f9e-45cf-8d40-3b17b46779a3",                        [{"alignmentgroup":"True","hovertemplate":"Name=%{x}<br>Percentage Change (%)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["M&M","Maruti","TATA MOTORS"],"xaxis":"x","y":[325.442573402418,86.5322281530696,862.7719962157048],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histog
# ...

# %%
daily_returns = close_v_comp.pct_change().dropna()

# Recalculating average daily return and standard deviation (risk)
avg_daily_return = daily_returns.mean()
risk = daily_returns.std()

# Creating a DataFrame for plotting
risk_return_df = pd.DataFrame({'Risk': risk, 'Average Daily Return': avg_daily_return})

fig = go.Figure()

# Add scatter plot points
fig.add_trace(go.Scatter(
    x=risk_return_df['Risk'],
    y=risk_return_df['Average Daily Return'],
    mode='markers+text',
    text=risk_return_df.index,
    textposition="top center",
    marker=dict(size=10)
))

# Update layout
fig.update_layout(
    title='Risk vs. Return Analysis',
    xaxis_title='Risk (Standard Deviation)',
    yaxis_title='Average Daily Return',
    showlegend=False
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="6ca9300c-16c1-433c-9c52-94908e6e3a25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ca9300c-16c1-433c-9c52-94908e6e3a25")) {                    Plotly.newPlot(                        "6ca9300c-16c1-433c-9c52-94908e6e3a25",                        [{"marker":{"size":10},"mode":"markers+text","text":["M&M","Maruti","TATA MOTORS"],"textposition":"top center","x":[0.021695940300698238,0.01986472222475607,0.0273492055019703],"y":[0.001692164799909116,0.0008255983737281771,0.0026512601757589112],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.
# ...
